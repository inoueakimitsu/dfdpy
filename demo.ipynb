# %%
from dfdpy.python import make_dfd, MermaidJsGraphExporter
process_node_list, data_store_node_list, edges = make_dfd(source="""
np.random.seed(123)

n_classes = 15
n_bags = 200
n_max_instance_in_one_bag = 1000
n_instances_of_each_bags = [np.random.randint(low=0, high=n_max_instance_in_one_bag) for _ in range(n_bags)]
class_labels_of_instance_in_bags = generate_instance(n_classes, n_instances_of_each_bags)
count_each_class_of_instance_in_bags = [
    pd.Series(x).value_counts().to_dict() for x in class_labels_of_instance_in_bags
]
count_each_class_of_instance_in_bags_matrix = \
    pd.DataFrame(count_each_class_of_instance_in_bags)[list(range(n_classes))].values
count_each_class_of_instance_in_bags_matrix = np.nan_to_num(count_each_class_of_instance_in_bags_matrix)
lower_threshold = np.zeros_like(count_each_class_of_instance_in_bags_matrix)
upper_threshold = np.zeros_like(count_each_class_of_instance_in_bags_matrix)
divisions = [0, 50, 100, 200, 1000, n_max_instance_in_one_bag]
for i_bag in range(n_bags):
    for i_class in range(n_classes):
        positive_count = count_each_class_of_instance_in_bags_matrix[i_bag, i_class]
        for i_division in range(len(divisions)-1):
            if divisions[i_division] <= positive_count and positive_count < divisions[i_division+1]:
                lower_threshold[i_bag, i_class] = divisions[i_division]
                upper_threshold[i_bag, i_class] = divisions[i_division+1]

n_fatures = 7
x_min = 0
x_max = 100
cov_diag = 0.1*40**2

means_of_classes = [np.random.uniform(low=x_min, high=x_max, size=n_fatures) for _ in range(n_classes)]
covs_of_classes = [np.eye(n_fatures)*cov_diag for _ in range(n_classes)]
bags = [
    np.vstack([
        np.random.multivariate_normal(
            means_of_classes[class_label],
            covs_of_classes[class_label],
            size=1) for class_label in class_labels_of_instance_in_bag
    ]) for class_labels_of_instance_in_bag in class_labels_of_instance_in_bags
]

true_y = [np.array([class_label for class_label in class_labels_of_instance_in_bag]) for class_labels_of_instance_in_bag in class_labels_of_instance_in_bags]

flatten_features = np.vstack(bags)
max_n_clusters = 500
# cluster_generator = KMeans(n_clusters=max_n_clusters, random_state=0)
# cluster_generator = DBSCAN()# KMeans(n_clusters=n_clusters, random_state=0)
cluster_generator = MiniBatchKMeans(n_clusters=max_n_clusters, random_state=0)
insample_estimated_clusters = cluster_generator.fit_predict(flatten_features)
n_clusters = np.max(insample_estimated_clusters) + 1
print("n_clusters:", n_clusters)

cluster_encoder = OneHotEncoder(sparse=False)
cluster_encoder.fit(np.array([np.arange(n_clusters)]).T)

milclassifier = generate_mil_classifier(
    cluster_generator,
    cluster_encoder,
    bags,
    lower_threshold,
    upper_threshold,
    n_clusters)

df_confusion_matrix = pd.crosstab(np.hstack(true_y), milclassifier.predict(np.vstack(bags)))

print("confusion matrix")
print(df_confusion_matrix)
""", hidden_id_list=[])
exporter = MermaidJsGraphExporter(graph_orientation="LR")
print(exporter.export(process_node_list=process_node_list, data_store_node_list=data_store_node_list, edges=edges))
# Out:
# graph LR;
# L7-L7("n_instances_of_each_bags&nbsp;=&nbsp;[np.random.randint(low=0,&nbsp;high=n_max_instance_in_one_bag)&nbsp;for&nbsp;_&nbsp;in&nbsp;range(n_bags)]<br />[Line 7-7]");
# style L7-L7 text-align:left;
# L8-L8("class_labels_of_instance_in_bags&nbsp;=&nbsp;generate_instance(n_classes,&nbsp;n_instances_of_each_bags)<br />[Line 8-8]");
# style L8-L8 text-align:left;
# L9-L11("count_each_class_of_instance_in_bags&nbsp;=&nbsp;[<br />&nbsp;&nbsp;&nbsp;&nbsp;pd.Series(x).value_counts().to_dict()&nbsp;for&nbsp;x&nbsp;in&nbsp;class_labels_of_instance_in_bags<br />]<br />[Line 9-11]");
# style L9-L11 text-align:left;
# L12-L12("count_each_class_of_instance_in_bags_matrix&nbsp;=&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;pd.DataFrame(count_each_class_of_instance_in_bags)[list(range(n_classes))].values<br />[Line 12-12]");
# style L12-L12 text-align:left;
# L13-L13("count_each_class_of_instance_in_bags_matrix&nbsp;=&nbsp;np.nan_to_num(count_each_class_of_instance_in_bags_matrix)<br />[Line 13-13]");
# style L13-L13 text-align:left;
# L14-L14("lower_threshold&nbsp;=&nbsp;np.zeros_like(count_each_class_of_instance_in_bags_matrix)<br />[Line 14-14]");
# style L14-L14 text-align:left;
# L15-L15("upper_threshold&nbsp;=&nbsp;np.zeros_like(count_each_class_of_instance_in_bags_matrix)<br />[Line 15-15]");
# style L15-L15 text-align:left;
# L16-L16("divisions&nbsp;=&nbsp;[0,&nbsp;50,&nbsp;100,&nbsp;200,&nbsp;1000,&nbsp;n_max_instance_in_one_bag]<br />[Line 16-16]");
# style L16-L16 text-align:left;
# L17-L23("for&nbsp;i_bag&nbsp;in&nbsp;range(n_bags):<br />&nbsp;&nbsp;&nbsp;&nbsp;for&nbsp;i_class&nbsp;in&nbsp;range(n_classes):<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;positive_count&nbsp;=&nbsp;count_each_class_of_instance_in_bags_matrix[i_bag,&nbsp;i_class]<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;for&nbsp;i_division&nbsp;in&nbsp;range(len(divisions)-1):<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;if&nbsp;divisions[i_division]&nbsp;&lt;=&nbsp;positive_count&nbsp;and&nbsp;positive_count&nbsp;&lt;&nbsp;divisions[i_division+1]:<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;lower_threshold[i_bag,&nbsp;i_class]&nbsp;=&nbsp;divisions[i_division]<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;upper_threshold[i_bag,&nbsp;i_class]&nbsp;=&nbsp;divisions[i_division+1]<br />[Line 17-23]");
# style L17-L23 text-align:left;
# L30-L30("means_of_classes&nbsp;=&nbsp;[np.random.uniform(low=x_min,&nbsp;high=x_max,&nbsp;size=n_fatures)&nbsp;for&nbsp;_&nbsp;in&nbsp;range(n_classes)]<br />[Line 30-30]");
# style L30-L30 text-align:left;
# L31-L31("covs_of_classes&nbsp;=&nbsp;[np.eye(n_fatures)*cov_diag&nbsp;for&nbsp;_&nbsp;in&nbsp;range(n_classes)]<br />[Line 31-31]");
# style L31-L31 text-align:left;
# L32-L39("bags&nbsp;=&nbsp;[<br />&nbsp;&nbsp;&nbsp;&nbsp;np.vstack([<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;np.random.multivariate_normal(<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;means_of_classes[class_label],<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;covs_of_classes[class_label],<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;size=1)&nbsp;for&nbsp;class_label&nbsp;in&nbsp;class_labels_of_instance_in_bag<br />&nbsp;&nbsp;&nbsp;&nbsp;])&nbsp;for&nbsp;class_labels_of_instance_in_bag&nbsp;in&nbsp;class_labels_of_instance_in_bags<br />]<br />[Line 32-39]");
# style L32-L39 text-align:left;
# L41-L41("true_y&nbsp;=&nbsp;[np.array([class_label&nbsp;for&nbsp;class_label&nbsp;in&nbsp;class_labels_of_instance_in_bag])&nbsp;for&nbsp;class_labels_of_instance_in_bag&nbsp;in&nbsp;class_labels_of_instance_in_bags]<br />[Line 41-41]");
# style L41-L41 text-align:left;
# L43-L43("flatten_features&nbsp;=&nbsp;np.vstack(bags)<br />[Line 43-43]");
# style L43-L43 text-align:left;
# L47-L47("cluster_generator&nbsp;=&nbsp;MiniBatchKMeans(n_clusters=max_n_clusters,&nbsp;random_state=0)<br />[Line 47-47]");
# style L47-L47 text-align:left;
# L48-L48("insample_estimated_clusters&nbsp;=&nbsp;cluster_generator.fit_predict(flatten_features)<br />[Line 48-48]");
# style L48-L48 text-align:left;
# L49-L49("n_clusters&nbsp;=&nbsp;np.max(insample_estimated_clusters)&nbsp;+&nbsp;1<br />[Line 49-49]");
# style L49-L49 text-align:left;
# L52-L52("cluster_encoder&nbsp;=&nbsp;OneHotEncoder(sparse=False)<br />[Line 52-52]");
# style L52-L52 text-align:left;
# L55-L61("milclassifier&nbsp;=&nbsp;generate_mil_classifier(<br />&nbsp;&nbsp;&nbsp;&nbsp;cluster_generator,<br />&nbsp;&nbsp;&nbsp;&nbsp;cluster_encoder,<br />&nbsp;&nbsp;&nbsp;&nbsp;bags,<br />&nbsp;&nbsp;&nbsp;&nbsp;lower_threshold,<br />&nbsp;&nbsp;&nbsp;&nbsp;upper_threshold,<br />&nbsp;&nbsp;&nbsp;&nbsp;n_clusters)<br />[Line 55-61]");
# style L55-L61 text-align:left;
# L63-L63("df_confusion_matrix&nbsp;=&nbsp;pd.crosstab(np.hstack(true_y),&nbsp;milclassifier.predict(np.vstack(bags)))<br />[Line 63-63]");
# style L63-L63 text-align:left;
# _["_"];
# n_max_instance_in_one_bag["n_max_instance_in_one_bag"];
# range["range"];
# n_bags["n_bags"];
# np["np"];
# n_instances_of_each_bags["n_instances_of_each_bags"];
# generate_instance["generate_instance"];
# n_classes["n_classes"];
# n_instances_of_each_bags["n_instances_of_each_bags"];
# class_labels_of_instance_in_bags["class_labels_of_instance_in_bags"];
# x["x"];
# class_labels_of_instance_in_bags["class_labels_of_instance_in_bags"];
# pd["pd"];
# count_each_class_of_instance_in_bags["count_each_class_of_instance_in_bags"];
# count_each_class_of_instance_in_bags["count_each_class_of_instance_in_bags"];
# list["list"];
# pd["pd"];
# range["range"];
# n_classes["n_classes"];
# count_each_class_of_instance_in_bags_matrix["count_each_class_of_instance_in_bags_matrix"];
# count_each_class_of_instance_in_bags_matrix["count_each_class_of_instance_in_bags_matrix"];
# np["np"];
# count_each_class_of_instance_in_bags_matrix'["count_each_class_of_instance_in_bags_matrix'"];
# count_each_class_of_instance_in_bags_matrix'["count_each_class_of_instance_in_bags_matrix'"];
# np["np"];
# lower_threshold["lower_threshold"];
# count_each_class_of_instance_in_bags_matrix'["count_each_class_of_instance_in_bags_matrix'"];
# np["np"];
# upper_threshold["upper_threshold"];
# n_max_instance_in_one_bag["n_max_instance_in_one_bag"];
# divisions["divisions"];
# range["range"];
# n_bags["n_bags"];
# range["range"];
# n_classes["n_classes"];
# count_each_class_of_instance_in_bags_matrix'["count_each_class_of_instance_in_bags_matrix'"];
# i_bag["i_bag"];
# i_class["i_class"];
# range["range"];
# len["len"];
# divisions["divisions"];
# divisions["divisions"];
# i_division["i_division"];
# divisions["divisions"];
# i_division["i_division"];
# i_bag'''["i_bag'''"];
# i_class'''["i_class'''"];
# positive_count["positive_count"];
# i_division'["i_division'"];
# lower_threshold'["lower_threshold'"];
# i_bag'''["i_bag'''"];
# i_class'''["i_class'''"];
# upper_threshold'["upper_threshold'"];
# i_bag'''["i_bag'''"];
# i_class'''["i_class'''"];
# _["_"];
# x_min["x_min"];
# x_max["x_max"];
# n_fatures["n_fatures"];
# range["range"];
# n_classes["n_classes"];
# np["np"];
# means_of_classes["means_of_classes"];
# cov_diag["cov_diag"];
# _["_"];
# n_fatures["n_fatures"];
# range["range"];
# n_classes["n_classes"];
# np["np"];
# covs_of_classes["covs_of_classes"];
# class_labels_of_instance_in_bag["class_labels_of_instance_in_bag"];
# class_labels_of_instance_in_bags["class_labels_of_instance_in_bags"];
# np["np"];
# class_label["class_label"];
# class_labels_of_instance_in_bag["class_labels_of_instance_in_bag"];
# means_of_classes["means_of_classes"];
# class_label["class_label"];
# covs_of_classes["covs_of_classes"];
# class_label["class_label"];
# np["np"];
# bags["bags"];
# class_labels_of_instance_in_bag["class_labels_of_instance_in_bag"];
# class_labels_of_instance_in_bags["class_labels_of_instance_in_bags"];
# np["np"];
# class_label["class_label"];
# true_y["true_y"];
# bags["bags"];
# np["np"];
# flatten_features["flatten_features"];
# MiniBatchKMeans["MiniBatchKMeans"];
# max_n_clusters["max_n_clusters"];
# cluster_generator["cluster_generator"];
# flatten_features["flatten_features"];
# cluster_generator["cluster_generator"];
# insample_estimated_clusters["insample_estimated_clusters"];
# insample_estimated_clusters["insample_estimated_clusters"];
# np["np"];
# n_clusters["n_clusters"];
# OneHotEncoder["OneHotEncoder"];
# cluster_encoder["cluster_encoder"];
# generate_mil_classifier["generate_mil_classifier"];
# cluster_generator["cluster_generator"];
# cluster_encoder["cluster_encoder"];
# bags["bags"];
# lower_threshold'["lower_threshold'"];
# upper_threshold'["upper_threshold'"];
# n_clusters["n_clusters"];
# milclassifier["milclassifier"];
# pd["pd"];
# true_y["true_y"];
# np["np"];
# milclassifier["milclassifier"];
# bags["bags"];
# df_confusion_matrix["df_confusion_matrix"];
# _ --> L7-L7;
# n_max_instance_in_one_bag --> L7-L7;
# range --> L7-L7;
# n_bags --> L7-L7;
# np --> L7-L7;
# L7-L7 --> n_instances_of_each_bags;
# generate_instance --> L8-L8;
# n_classes --> L8-L8;
# n_instances_of_each_bags --> L8-L8;
# L8-L8 --> class_labels_of_instance_in_bags;
# x --> L9-L11;
# class_labels_of_instance_in_bags --> L9-L11;
# pd --> L9-L11;
# L9-L11 --> count_each_class_of_instance_in_bags;
# count_each_class_of_instance_in_bags --> L12-L12;
# list --> L12-L12;
# pd --> L12-L12;
# range --> L12-L12;
# n_classes --> L12-L12;
# L12-L12 --> count_each_class_of_instance_in_bags_matrix;
# count_each_class_of_instance_in_bags_matrix --> L13-L13;
# np --> L13-L13;
# L13-L13 --> count_each_class_of_instance_in_bags_matrix';
# count_each_class_of_instance_in_bags_matrix' --> L14-L14;
# np --> L14-L14;
# L14-L14 --> lower_threshold;
# count_each_class_of_instance_in_bags_matrix' --> L15-L15;
# np --> L15-L15;
# L15-L15 --> upper_threshold;
# n_max_instance_in_one_bag --> L16-L16;
# L16-L16 --> divisions;
# range --> L17-L23;
# n_bags --> L17-L23;
# range --> L17-L23;
# n_classes --> L17-L23;
# count_each_class_of_instance_in_bags_matrix' --> L17-L23;
# i_bag --> L17-L23;
# i_class --> L17-L23;
# range --> L17-L23;
# len --> L17-L23;
# divisions --> L17-L23;
# divisions --> L17-L23;
# i_division --> L17-L23;
# divisions --> L17-L23;
# i_division --> L17-L23;
# L17-L23 --> i_bag''';
# L17-L23 --> i_class''';
# L17-L23 --> positive_count;
# L17-L23 --> i_division';
# L17-L23 --> lower_threshold';
# L17-L23 --> i_bag''';
# L17-L23 --> i_class''';
# L17-L23 --> upper_threshold';
# L17-L23 --> i_bag''';
# L17-L23 --> i_class''';
# _ --> L30-L30;
# x_min --> L30-L30;
# x_max --> L30-L30;
# n_fatures --> L30-L30;
# range --> L30-L30;
# n_classes --> L30-L30;
# np --> L30-L30;
# L30-L30 --> means_of_classes;
# cov_diag --> L31-L31;
# _ --> L31-L31;
# n_fatures --> L31-L31;
# range --> L31-L31;
# n_classes --> L31-L31;
# np --> L31-L31;
# L31-L31 --> covs_of_classes;
# class_labels_of_instance_in_bag --> L32-L39;
# class_labels_of_instance_in_bags --> L32-L39;
# np --> L32-L39;
# class_label --> L32-L39;
# class_labels_of_instance_in_bag --> L32-L39;
# means_of_classes --> L32-L39;
# class_label --> L32-L39;
# covs_of_classes --> L32-L39;
# class_label --> L32-L39;
# np --> L32-L39;
# L32-L39 --> bags;
# class_labels_of_instance_in_bag --> L41-L41;
# class_labels_of_instance_in_bags --> L41-L41;
# np --> L41-L41;
# class_label --> L41-L41;
# L41-L41 --> true_y;
# bags --> L43-L43;
# np --> L43-L43;
# L43-L43 --> flatten_features;
# MiniBatchKMeans --> L47-L47;
# max_n_clusters --> L47-L47;
# L47-L47 --> cluster_generator;
# flatten_features --> L48-L48;
# cluster_generator --> L48-L48;
# L48-L48 --> insample_estimated_clusters;
# insample_estimated_clusters --> L49-L49;
# np --> L49-L49;
# L49-L49 --> n_clusters;
# OneHotEncoder --> L52-L52;
# L52-L52 --> cluster_encoder;
# generate_mil_classifier --> L55-L61;
# cluster_generator --> L55-L61;
# cluster_encoder --> L55-L61;
# bags --> L55-L61;
# lower_threshold' --> L55-L61;
# upper_threshold' --> L55-L61;
# n_clusters --> L55-L61;
# L55-L61 --> milclassifier;
# pd --> L63-L63;
# true_y --> L63-L63;
# np --> L63-L63;
# milclassifier --> L63-L63;
# bags --> L63-L63;
# L63-L63 --> df_confusion_matrix;
